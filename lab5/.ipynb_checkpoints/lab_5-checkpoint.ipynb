# %% [markdown]
# ## Lab #5:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
    # Setup target directory (we'll view images from here)
    target_folder = target_dir + target_class

    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)

    # Read in the image and plot it using matplotlib
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off");

    print(f"Image shape: {img.shape}") # show the shape of the image

    return img

# %%
secure_random = random.SystemRandom()
plt.figure(figsize=(10,30))
for i in range(4):
    choice = secure_random.choice(['breakfast_burrito', 'foie_gras', 'oysters'])
    plt.subplots()
    plt.grid('off')
    plt.imshow(view_random_image(target_dir="data/3_food/train/", target_class=choice))
# Out:
# Image shape: (512, 512, 3)
# Image shape: (512, 384, 3)
# Image shape: (512, 512, 3)
# Image shape: (512, 341, 3)

# %%
train_path = 'data/3_food/train'
test_path = 'data/3_food/train'

# %%
IMAGE_SIZE = (224, 224)

# %%
img_classes = os.listdir(train_path)
img_classes
# Out:
# ['breakfast_burrito', 'foie_gras', 'oysters']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
seed = 42

# Set the seed
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ### Reading data:

# %%
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=20, # rotate the image slightly between 0 and 20 degrees (note: this is an int not a float)
                                             shear_range=0.2, # shear the image
                                             zoom_range=0.2, # zoom into the image
                                             width_shift_range=0.2, # shift the image width ways
                                             height_shift_range=0.2, # shift the image height ways
                                             horizontal_flip=True) # flip the image on the horizontal axis

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data_augmented = train_datagen_augmented.flow_from_directory(test_path,
                                                                   target_size=IMAGE_SIZE,
                                                                   batch_size=32,
                                                                   class_mode='categorical')

test_data = test_datagen.flow_from_directory(train_path,
                                             target_size=IMAGE_SIZE,
                                             batch_size=32,
                                             class_mode='categorical')
# Out:
# Found 225 images belonging to 3 classes.
# Found 225 images belonging to 3 classes.

# %%
# Plot the validation and training data separately
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
import tensorflow_hub as hub
import datetime

# %%
def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# %% [markdown]
# ### Neural Networks comparison:

# %% [markdown]
# #### CNN -  Adam optimizer:

# %%
tf.random.set_seed(seed)

cnn_model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=32,
                           kernel_size=3,
                           activation='relu',
                           input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(filters=64,
                           kernel_size=3,
                           activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(filters=128,
                           kernel_size=3,
                           activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(filters=256,
                           kernel_size=3,
                           activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(3,
                          activation='softmax')
])

# %%
tf.random.set_seed(seed)

cnn_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

cnn_history = cnn_model.fit(train_data_augmented,
                            epochs=10,
                            steps_per_epoch=len(train_data_augmented),
                            validation_data=test_data,
                            validation_steps=len(test_data), 
                            callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                   experiment_name="cnn_model")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/cnn_model/20211201-224336
# Epoch 1/10
# 8/8 [==============================] - 14s 2s/step - loss: 1.1659 - accuracy: 0.3600 - val_loss: 1.0968 - val_accuracy: 0.3333
# Epoch 2/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.1151 - accuracy: 0.3378 - val_loss: 1.0989 - val_accuracy: 0.3378
# Epoch 3/10
# 8/8 [==============================] - 12s 2s/step - loss: 1.1082 - accuracy: 0.3422 - val_loss: 1.0981 - val_accuracy: 0.3333
# Epoch 4/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.0928 - accuracy: 0.3644 - val_loss: 1.0726 - val_accuracy: 0.3644
# Epoch 5/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.0799 - accuracy: 0.3822 - val_loss: 1.1507 - val_accuracy: 0.3333
# Epoch 6/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.1494 - accuracy: 0.3378 - val_loss: 1.0780 - val_accuracy: 0.4533
# Epoch 7/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.1041 - accuracy: 0.3733 - val_loss: 1.0820 - val_accuracy: 0.4400
# Epoch 8/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.0834 - accuracy: 0.4044 - val_loss: 1.0735 - val_accuracy: 0.3600
# Epoch 9/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.0821 - accuracy: 0.3822 - val_loss: 1.0698 - val_accuracy: 0.4133
# Epoch 10/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.0920 - accuracy: 0.4311 - val_loss: 1.0194 - val_accuracy: 0.4311

# %%
plot_loss_curves(cnn_history)

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 110595
# =================================================================
# Total params: 499,011
# Trainable params: 499,011
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Resnet - Adam optimizer

# %%
resnet_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'

# %%
def create_model(model_url, num_classes=10, input_shape=None):
    
    model = tf.keras.Sequential([
        hub.KerasLayer(model_url,
                       trainable=False,
                       input_shape=input_shape),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    return model

# %%
resnet_model = create_model(resnet_url, num_classes=len(img_classes), input_shape=IMAGE_SIZE+(3,))

# %%
tf.random.set_seed(seed)

# Compile
resnet_model.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

resnet_history = resnet_model.fit(train_data_augmented,
                                  epochs=10,
                                  steps_per_epoch=len(train_data_augmented),
                                  validation_data=test_data,
                                  validation_steps=len(test_data), 
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                   experiment_name="resnet_v2_50")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet_v2_50/20211201-224553
# Epoch 1/10
# 8/8 [==============================] - 36s 4s/step - loss: 1.0946 - accuracy: 0.4756 - val_loss: 0.7298 - val_accuracy: 0.6800
# Epoch 2/10
# 8/8 [==============================] - 26s 3s/step - loss: 0.7292 - accuracy: 0.6667 - val_loss: 0.5084 - val_accuracy: 0.8267
# Epoch 3/10
# 8/8 [==============================] - 26s 3s/step - loss: 0.5720 - accuracy: 0.8000 - val_loss: 0.4434 - val_accuracy: 0.8044
# Epoch 4/10
# 8/8 [==============================] - 25s 4s/step - loss: 0.4301 - accuracy: 0.8489 - val_loss: 0.2982 - val_accuracy: 0.8933
# Epoch 5/10
# 8/8 [==============================] - 26s 3s/step - loss: 0.3257 - accuracy: 0.8978 - val_loss: 0.2629 - val_accuracy: 0.9111
# Epoch 6/10
# 8/8 [==============================] - 27s 4s/step - loss: 0.3170 - accuracy: 0.9067 - val_loss: 0.2257 - val_accuracy: 0.9244
# Epoch 7/10
# 8/8 [==============================] - 28s 4s/step - loss: 0.2885 - accuracy: 0.8978 - val_loss: 0.2041 - val_accuracy: 0.9333
# Epoch 8/10
# 8/8 [==============================] - 27s 4s/step - loss: 0.2472 - accuracy: 0.9244 - val_loss: 0.1866 - val_accuracy: 0.9511
# Epoch 9/10
# 8/8 [==============================] - 27s 4s/step - loss: 0.2344 - accuracy: 0.9200 - val_loss: 0.1692 - val_accuracy: 0.9556
# Epoch 10/10
# 8/8 [==============================] - 27s 4s/step - loss: 0.2272 - accuracy: 0.9111 - val_loss: 0.1570 - val_accuracy: 0.9600

# %%
plot_loss_curves(resnet_history)

# %%
resnet_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 2048)              23564800
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 6147
# =================================================================
# Total params: 23,570,947
# Trainable params: 6,147
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# #### EfficientNet - Adam optimizer

# %%
efficientnet_url = 'https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1'

# %%
efficientnet_model = create_model(efficientnet_url, num_classes=len(img_classes), input_shape=IMAGE_SIZE+(3,))

# %%
tf.random.set_seed(seed)

# Compile
efficientnet_model.compile(loss='categorical_crossentropy',
                           optimizer=tf.keras.optimizers.Adam(),
                           metrics=['accuracy'])

efficientnet_history = efficientnet_model.fit(train_data_augmented,
                                              epochs=10,
                                              steps_per_epoch=len(train_data_augmented),
                                              validation_data=test_data,
                                              validation_steps=len(test_data), 
                                              callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                                     experiment_name="efficientnet")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/efficientnet/20211201-225101
# Epoch 1/10
# 8/8 [==============================] - 49s 5s/step - loss: 1.0134 - accuracy: 0.4622 - val_loss: 0.7735 - val_accuracy: 0.7333
# Epoch 2/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.7310 - accuracy: 0.7644 - val_loss: 0.5737 - val_accuracy: 0.8667
# Epoch 3/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.5759 - accuracy: 0.8444 - val_loss: 0.4494 - val_accuracy: 0.8889
# Epoch 4/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.4731 - accuracy: 0.8756 - val_loss: 0.3739 - val_accuracy: 0.9156
# Epoch 5/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.3965 - accuracy: 0.8933 - val_loss: 0.3183 - val_accuracy: 0.9422
# Epoch 6/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.3610 - accuracy: 0.9111 - val_loss: 0.2789 - val_accuracy: 0.9511
# Epoch 7/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.3186 - accuracy: 0.9200 - val_loss: 0.2484 - val_accuracy: 0.9556
# Epoch 8/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.2927 - accuracy: 0.9289 - val_loss: 0.2291 - val_accuracy: 0.9689
# Epoch 9/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.2682 - accuracy: 0.9378 - val_loss: 0.2132 - val_accuracy: 0.9689
# Epoch 10/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.2303 - accuracy: 0.9511 - val_loss: 0.1951 - val_accuracy: 0.9644

# %%
plot_loss_curves(efficientnet_history)

# %%
efficientnet_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 1280)              4049564
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 4,053,407
# Trainable params: 3,843
# Non-trainable params: 4,049,564
# _________________________________________________________________

# %% [markdown]
# #### Resnet (optimizer SGD)

# %%
tf.random.set_seed(seed)

# Compile
resnet_model.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.SGD(),
                     metrics=['accuracy'])

resnet_sgd_history = resnet_model.fit(train_data_augmented,
                                  epochs=5,
                                  steps_per_epoch=len(train_data_augmented),
                                  validation_data=test_data,
                                  validation_steps=len(test_data), 
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                   experiment_name="resnet_v2_50_sgd")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet_v2_50_sgd/20211201-225423
# Epoch 1/5
# 8/8 [==============================] - 42s 6s/step - loss: 0.2330 - accuracy: 0.9022 - val_loss: 0.1452 - val_accuracy: 0.9556
# Epoch 2/5
# 8/8 [==============================] - 27s 4s/step - loss: 0.2343 - accuracy: 0.9200 - val_loss: 0.1525 - val_accuracy: 0.9600
# Epoch 3/5
# 8/8 [==============================] - 28s 4s/step - loss: 0.2007 - accuracy: 0.9289 - val_loss: 0.1322 - val_accuracy: 0.9511
# Epoch 4/5
# 8/8 [==============================] - 28s 4s/step - loss: 0.1616 - accuracy: 0.9556 - val_loss: 0.1266 - val_accuracy: 0.9689
# Epoch 5/5
# 8/8 [==============================] - 28s 4s/step - loss: 0.2126 - accuracy: 0.9289 - val_loss: 0.1147 - val_accuracy: 0.9822

# %% [markdown]
# #### EfficientNet - SGD optimizer

# %%
tf.random.set_seed(seed)

# Compile
efficientnet_model.compile(loss='categorical_crossentropy',
                           optimizer=tf.keras.optimizers.SGD(),
                           metrics=['accuracy'])

efficientnet_sgd_history = efficientnet_model.fit(train_data_augmented,
                                              epochs=5,
                                              steps_per_epoch=len(train_data_augmented),
                                              validation_data=test_data,
                                              validation_steps=len(test_data), 
                                              callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                                     experiment_name="efficientnet_sgd")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/efficientnet_sgd/20211201-225657
# Epoch 1/5
# 8/8 [==============================] - 45s 6s/step - loss: 0.2431 - accuracy: 0.9289 - val_loss: 0.1913 - val_accuracy: 0.9644
# Epoch 2/5
# 8/8 [==============================] - 17s 2s/step - loss: 0.2154 - accuracy: 0.9511 - val_loss: 0.1865 - val_accuracy: 0.9689
# Epoch 3/5
# 8/8 [==============================] - 17s 2s/step - loss: 0.2208 - accuracy: 0.9556 - val_loss: 0.1818 - val_accuracy: 0.9644
# Epoch 4/5
# 8/8 [==============================] - 17s 2s/step - loss: 0.2215 - accuracy: 0.9600 - val_loss: 0.1776 - val_accuracy: 0.9644
# Epoch 5/5
# 8/8 [==============================] - 17s 2s/step - loss: 0.2114 - accuracy: 0.9600 - val_loss: 0.1742 - val_accuracy: 0.9689

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# Clear any logs from previous runs
# rm -rf ./tensorflow_hub/

# %%
# %tensorboard --logdir ./tensorflow_hub/
# %tensorboard --logdir=./tensorflow_hub/ --host localhost --port 8088
# Out:
# Reusing TensorBoard on port 8088 (pid 18936), started 0:07:01 ago. (Use '!kill 18936' to kill it.)
#       <iframe id="tensorboard-frame-cec9fd3f90d2e942" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cec9fd3f90d2e942");
#           const url = new URL("/", window.location);
#           const port = 8088;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from IPython.display import SVG

# %%
svg_image_dir = './graphs'

# %%
svg_plots = ['epoch_accuracy.svg', 'epoch_loss.svg', 'evaluation_loss_vs_iterations.svg', 'evaluation_accuracy_vs_iterations.svg']

# %% [markdown]
# ### Plots:

# %% [markdown]
# #### Epoch accuracy

# %%
SVG(os.path.join(svg_image_dir, 'epoch_accuracy.svg'))

# %% [markdown]
# #### Epoch loss

# %%
SVG(os.path.join(svg_image_dir, 'epoch_loss.svg'))

# %% [markdown]
# #### Evaluation loss | iterations

# %%
SVG(os.path.join(svg_image_dir, 'evaluation_loss_vs_iterations.svg'))

# %% [markdown]
# #### Evaluation accuracy | iterations

# %%
SVG(os.path.join(svg_image_dir, 'evaluation_accuracy_vs_iterations.svg'))

# %% [markdown]
# 1.6 (1.7) Моделі 1.2,1.3 отримані за допомогою tf.keras.applications та треновані з використанням fine-tuning (останні 10 шарів)

# %%
def model_trainable_layers(model):
    for layer_number, layer in enumerate(model.layers):
        print(layer_number, layer.name, layer.trainable, len(layer.trainable_variables))

# %% [markdown]
# ### Fine-tuning:

# %% [markdown]
# #### Resnet + fine-tuning

# %%
resnet_tune = tf.keras.applications.ResNet50V2(include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3),
        pooling='max',
        classes=3,
        classifier_activation='softmax')

# %%
# Fine-tuning last 10 layers
resnet_tune.trainable = False

for layer in resnet_tune.layers[-10:]:
    layer.trainable = True

# %%
model_trainable_layers(resnet_tune)[-10]
# Out:
# 0 input_17 False 0
# 1 conv1_pad False 0
# 2 conv1_conv False 0
# 3 pool1_pad False 0
# 4 pool1_pool False 0
# 5 conv2_block1_preact_bn False 0
# 6 conv2_block1_preact_relu False 0
# 7 conv2_block1_1_conv False 0
# 8 conv2_block1_1_bn False 0
# 9 conv2_block1_1_relu False 0
# 10 conv2_block1_2_pad False 0
# 11 conv2_block1_2_conv False 0
# 12 conv2_block1_2_bn False 0
# 13 conv2_block1_2_relu False 0
# 14 conv2_block1_0_conv False 0
# 15 conv2_block1_3_conv False 0
# 16 conv2_block1_out False 0
# 17 conv2_block2_preact_bn False 0
# 18 conv2_block2_preact_relu False 0
# 19 conv2_block2_1_conv False 0
# 20 conv2_block2_1_bn False 0
# 21 conv2_block2_1_relu False 0
# 22 conv2_block2_2_pad False 0
# 23 conv2_block2_2_conv False 0
# 24 conv2_block2_2_bn False 0
# 25 conv2_block2_2_relu False 0
# 26 conv2_block2_3_conv False 0
# 27 conv2_block2_out False 0
# 28 conv2_block3_preact_bn False 0
# 29 conv2_block3_preact_relu False 0
# 30 conv2_block3_1_conv False 0
# 31 conv2_block3_1_bn False 0
# 32 conv2_block3_1_relu False 0
# 33 conv2_block3_2_pad False 0
# 34 conv2_block3_2_conv False 0
# 35 conv2_block3_2_bn False 0
# 36 conv2_block3_2_relu False 0
# 37 max_pooling2d_49 False 0
# 38 conv2_block3_3_conv False 0
# 39 conv2_block3_out False 0
# 40 conv3_block1_preact_bn False 0
# 41 conv3_block1_preact_relu False 0
# 42 conv3_block1_1_conv False 0
# 43 conv3_block1_1_bn False 0
# 44 conv3_block1_1_relu False 0
# 45 conv3_block1_2_pad False 0
# 46 conv3_block1_2_conv False 0
# 47 conv3_block1_2_bn False 0
# 48 conv3_block1_2_relu False 0
# 49 conv3_block1_0_conv False 0
# 50 conv3_block1_3_conv False 0
# 51 conv3_block1_out False 0
# 52 conv3_block2_preact_bn False 0
# 53 conv3_block2_preact_relu False 0
# 54 conv3_block2_1_conv False 0
# 55 conv3_block2_1_bn False 0
# 56 conv3_block2_1_relu False 0
# 57 conv3_block2_2_pad False 0
# 58 conv3_block2_2_conv False 0
# 59 conv3_block2_2_bn False 0
# 60 conv3_block2_2_relu False 0
# 61 conv3_block2_3_conv False 0
# 62 conv3_block2_out False 0
# 63 conv3_block3_preact_bn False 0
# 64 conv3_block3_preact_relu False 0
# 65 conv3_block3_1_conv False 0
# 66 conv3_block3_1_bn False 0
# 67 conv3_block3_1_relu False 0
# 68 conv3_block3_2_pad False 0
# 69 conv3_block3_2_conv False 0
# 70 conv3_block3_2_bn False 0
# 71 conv3_block3_2_relu False 0
# 72 conv3_block3_3_conv False 0
# 73 conv3_block3_out False 0
# 74 conv3_block4_preact_bn False 0
# 75 conv3_block4_preact_relu False 0
# 76 conv3_block4_1_conv False 0
# 77 conv3_block4_1_bn False 0
# 78 conv3_block4_1_relu False 0
# 79 conv3_block4_2_pad False 0
# 80 conv3_block4_2_conv False 0
# 81 conv3_block4_2_bn False 0
# 82 conv3_block4_2_relu False 0
# 83 max_pooling2d_50 False 0
# 84 conv3_block4_3_conv False 0
# 85 conv3_block4_out False 0
# 86 conv4_block1_preact_bn False 0
# 87 conv4_block1_preact_relu False 0
# 88 conv4_block1_1_conv False 0
# 89 conv4_block1_1_bn False 0
# 90 conv4_block1_1_relu False 0
# 91 conv4_block1_2_pad False 0
# 92 conv4_block1_2_conv False 0
# 93 conv4_block1_2_bn False 0
# 94 conv4_block1_2_relu False 0
# 95 conv4_block1_0_conv False 0
# 96 conv4_block1_3_conv False 0
# 97 conv4_block1_out False 0
# 98 conv4_block2_preact_bn False 0
# 99 conv4_block2_preact_relu False 0
# 100 conv4_block2_1_conv False 0
# 101 conv4_block2_1_bn False 0
# 102 conv4_block2_1_relu False 0
# 103 conv4_block2_2_pad False 0
# 104 conv4_block2_2_conv False 0
# 105 conv4_block2_2_bn False 0
# 106 conv4_block2_2_relu False 0
# 107 conv4_block2_3_conv False 0
# 108 conv4_block2_out False 0
# 109 conv4_block3_preact_bn False 0
# 110 conv4_block3_preact_relu False 0
# 111 conv4_block3_1_conv False 0
# 112 conv4_block3_1_bn False 0
# 113 conv4_block3_1_relu False 0
# 114 conv4_block3_2_pad False 0
# 115 conv4_block3_2_conv False 0
# 116 conv4_block3_2_bn False 0
# 117 conv4_block3_2_relu False 0
# 118 conv4_block3_3_conv False 0
# 119 conv4_block3_out False 0
# 120 conv4_block4_preact_bn False 0
# 121 conv4_block4_preact_relu False 0
# 122 conv4_block4_1_conv False 0
# 123 conv4_block4_1_bn False 0
# 124 conv4_block4_1_relu False 0
# 125 conv4_block4_2_pad False 0
# 126 conv4_block4_2_conv False 0
# 127 conv4_block4_2_bn False 0
# 128 conv4_block4_2_relu False 0
# 129 conv4_block4_3_conv False 0
# 130 conv4_block4_out False 0
# 131 conv4_block5_preact_bn False 0
# 132 conv4_block5_preact_relu False 0
# 133 conv4_block5_1_conv False 0
# 134 conv4_block5_1_bn False 0
# 135 conv4_block5_1_relu False 0
# 136 conv4_block5_2_pad False 0
# 137 conv4_block5_2_conv False 0
# 138 conv4_block5_2_bn False 0
# 139 conv4_block5_2_relu False 0
# 140 conv4_block5_3_conv False 0
# 141 conv4_block5_out False 0
# 142 conv4_block6_preact_bn False 0
# 143 conv4_block6_preact_relu False 0
# 144 conv4_block6_1_conv False 0
# 145 conv4_block6_1_bn False 0
# 146 conv4_block6_1_relu False 0
# 147 conv4_block6_2_pad False 0
# 148 conv4_block6_2_conv False 0
# 149 conv4_block6_2_bn False 0
# 150 conv4_block6_2_relu False 0
# 151 max_pooling2d_51 False 0
# 152 conv4_block6_3_conv False 0
# 153 conv4_block6_out False 0
# 154 conv5_block1_preact_bn False 0
# 155 conv5_block1_preact_relu False 0
# 156 conv5_block1_1_conv False 0
# 157 conv5_block1_1_bn False 0
# 158 conv5_block1_1_relu False 0
# 159 conv5_block1_2_pad False 0
# 160 conv5_block1_2_conv False 0
# 161 conv5_block1_2_bn False 0
# 162 conv5_block1_2_relu False 0
# 163 conv5_block1_0_conv False 0
# 164 conv5_block1_3_conv False 0
# 165 conv5_block1_out False 0
# 166 conv5_block2_preact_bn False 0
# 167 conv5_block2_preact_relu False 0
# 168 conv5_block2_1_conv False 0
# 169 conv5_block2_1_bn False 0
# 170 conv5_block2_1_relu False 0
# 171 conv5_block2_2_pad False 0
# 172 conv5_block2_2_conv False 0
# 173 conv5_block2_2_bn False 0
# 174 conv5_block2_2_relu False 0
# 175 conv5_block2_3_conv False 0
# 176 conv5_block2_out False 0
# 177 conv5_block3_preact_bn False 0
# 178 conv5_block3_preact_relu False 0
# 179 conv5_block3_1_conv False 0
# 180 conv5_block3_1_bn False 0
# 181 conv5_block3_1_relu True 0
# 182 conv5_block3_2_pad True 0
# 183 conv5_block3_2_conv True 1
# 184 conv5_block3_2_bn True 2
# 185 conv5_block3_2_relu True 0
# 186 conv5_block3_3_conv True 2
# 187 conv5_block3_out True 0
# 188 post_bn True 2
# 189 post_relu True 0
# 190 max_pool True 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14108/455856160.py in <module>
# ----> 1 model_trainable_layers(resnet_tune)[-10]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
resnet_fine_tuning_model = tf.keras.Sequential([
        resnet_tune,
        tf.keras.layers.Dense(3, activation='softmax')
    ])

# %%
tf.random.set_seed(seed)

# Compile
resnet_fine_tuning_model.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

resnet_fine_tuning_model_history = resnet_fine_tuning_model.fit(train_data_augmented,
                                  epochs=5,
                                  steps_per_epoch=len(train_data_augmented),
                                  validation_data=test_data,
                                  validation_steps=len(test_data), 
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                   experiment_name="resnet_v2_50_fine_tuning")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet_v2_50_fine_tuning/20211202-093314
# Epoch 1/5
# 8/8 [==============================] - 34s 4s/step - loss: 2.9787 - accuracy: 0.5111 - val_loss: 2.1833 - val_accuracy: 0.6400
# Epoch 2/5
# 8/8 [==============================] - 29s 4s/step - loss: 2.0174 - accuracy: 0.6400 - val_loss: 3.3888 - val_accuracy: 0.6089
# Epoch 3/5
# 8/8 [==============================] - 29s 4s/step - loss: 3.4057 - accuracy: 0.6267 - val_loss: 2.7868 - val_accuracy: 0.6489
# Epoch 4/5
# 8/8 [==============================] - 31s 4s/step - loss: 1.5773 - accuracy: 0.7378 - val_loss: 0.5136 - val_accuracy: 0.8933
# Epoch 5/5
# 8/8 [==============================] - 36s 5s/step - loss: 1.5010 - accuracy: 0.7644 - val_loss: 3.0770 - val_accuracy: 0.6844

# %% [markdown]
# #### EfficientNet + Fine-tuning

# %%
efficientnet_tune = tf.keras.applications.EfficientNetB0(include_top=False,
          weights='imagenet',
          input_shape=IMAGE_SIZE + (3,),
          pooling='max',
          classes=len(img_classes),
          classifier_activation='softmax')

# %%
# Fine-tuning last 10 layers
efficientnet_tune.trainable = False

for layer in efficientnet_tune.layers[-10:]:
    layer.trainable = True

# %%
model_trainable_layers(efficientnet_tune)
# Out:
# 0 input_18 False 0
# 1 rescaling_1 False 0
# 2 normalization_1 False 0
# 3 stem_conv_pad False 0
# 4 stem_conv False 0
# 5 stem_bn False 0
# 6 stem_activation False 0
# 7 block1a_dwconv False 0
# 8 block1a_bn False 0
# 9 block1a_activation False 0
# 10 block1a_se_squeeze False 0
# 11 block1a_se_reshape False 0
# 12 block1a_se_reduce False 0
# 13 block1a_se_expand False 0
# 14 block1a_se_excite False 0
# 15 block1a_project_conv False 0
# 16 block1a_project_bn False 0
# 17 block2a_expand_conv False 0
# 18 block2a_expand_bn False 0
# 19 block2a_expand_activation False 0
# 20 block2a_dwconv_pad False 0
# 21 block2a_dwconv False 0
# 22 block2a_bn False 0
# 23 block2a_activation False 0
# 24 block2a_se_squeeze False 0
# 25 block2a_se_reshape False 0
# 26 block2a_se_reduce False 0
# 27 block2a_se_expand False 0
# 28 block2a_se_excite False 0
# 29 block2a_project_conv False 0
# 30 block2a_project_bn False 0
# 31 block2b_expand_conv False 0
# 32 block2b_expand_bn False 0
# 33 block2b_expand_activation False 0
# 34 block2b_dwconv False 0
# 35 block2b_bn False 0
# 36 block2b_activation False 0
# 37 block2b_se_squeeze False 0
# 38 block2b_se_reshape False 0
# 39 block2b_se_reduce False 0
# 40 block2b_se_expand False 0
# 41 block2b_se_excite False 0
# 42 block2b_project_conv False 0
# 43 block2b_project_bn False 0
# 44 block2b_drop False 0
# 45 block2b_add False 0
# 46 block3a_expand_conv False 0
# 47 block3a_expand_bn False 0
# 48 block3a_expand_activation False 0
# 49 block3a_dwconv_pad False 0
# 50 block3a_dwconv False 0
# 51 block3a_bn False 0
# 52 block3a_activation False 0
# 53 block3a_se_squeeze False 0
# 54 block3a_se_reshape False 0
# 55 block3a_se_reduce False 0
# 56 block3a_se_expand False 0
# 57 block3a_se_excite False 0
# 58 block3a_project_conv False 0
# 59 block3a_project_bn False 0
# 60 block3b_expand_conv False 0
# 61 block3b_expand_bn False 0
# 62 block3b_expand_activation False 0
# 63 block3b_dwconv False 0
# 64 block3b_bn False 0
# 65 block3b_activation False 0
# 66 block3b_se_squeeze False 0
# 67 block3b_se_reshape False 0
# 68 block3b_se_reduce False 0
# 69 block3b_se_expand False 0
# 70 block3b_se_excite False 0
# 71 block3b_project_conv False 0
# 72 block3b_project_bn False 0
# 73 block3b_drop False 0
# 74 block3b_add False 0
# 75 block4a_expand_conv False 0
# 76 block4a_expand_bn False 0
# 77 block4a_expand_activation False 0
# 78 block4a_dwconv_pad False 0
# 79 block4a_dwconv False 0
# 80 block4a_bn False 0
# 81 block4a_activation False 0
# 82 block4a_se_squeeze False 0
# 83 block4a_se_reshape False 0
# 84 block4a_se_reduce False 0
# 85 block4a_se_expand False 0
# 86 block4a_se_excite False 0
# 87 block4a_project_conv False 0
# 88 block4a_project_bn False 0
# 89 block4b_expand_conv False 0
# 90 block4b_expand_bn False 0
# 91 block4b_expand_activation False 0
# 92 block4b_dwconv False 0
# 93 block4b_bn False 0
# 94 block4b_activation False 0
# 95 block4b_se_squeeze False 0
# 96 block4b_se_reshape False 0
# 97 block4b_se_reduce False 0
# 98 block4b_se_expand False 0
# 99 block4b_se_excite False 0
# 100 block4b_project_conv False 0
# 101 block4b_project_bn False 0
# 102 block4b_drop False 0
# 103 block4b_add False 0
# 104 block4c_expand_conv False 0
# 105 block4c_expand_bn False 0
# 106 block4c_expand_activation False 0
# 107 block4c_dwconv False 0
# 108 block4c_bn False 0
# 109 block4c_activation False 0
# 110 block4c_se_squeeze False 0
# 111 block4c_se_reshape False 0
# 112 block4c_se_reduce False 0
# 113 block4c_se_expand False 0
# 114 block4c_se_excite False 0
# 115 block4c_project_conv False 0
# 116 block4c_project_bn False 0
# 117 block4c_drop False 0
# 118 block4c_add False 0
# 119 block5a_expand_conv False 0
# 120 block5a_expand_bn False 0
# 121 block5a_expand_activation False 0
# 122 block5a_dwconv False 0
# 123 block5a_bn False 0
# 124 block5a_activation False 0
# 125 block5a_se_squeeze False 0
# 126 block5a_se_reshape False 0
# 127 block5a_se_reduce False 0
# 128 block5a_se_expand False 0
# 129 block5a_se_excite False 0
# 130 block5a_project_conv False 0
# 131 block5a_project_bn False 0
# 132 block5b_expand_conv False 0
# 133 block5b_expand_bn False 0
# 134 block5b_expand_activation False 0
# 135 block5b_dwconv False 0
# 136 block5b_bn False 0
# 137 block5b_activation False 0
# 138 block5b_se_squeeze False 0
# 139 block5b_se_reshape False 0
# 140 block5b_se_reduce False 0
# 141 block5b_se_expand False 0
# 142 block5b_se_excite False 0
# 143 block5b_project_conv False 0
# 144 block5b_project_bn False 0
# 145 block5b_drop False 0
# 146 block5b_add False 0
# 147 block5c_expand_conv False 0
# 148 block5c_expand_bn False 0
# 149 block5c_expand_activation False 0
# 150 block5c_dwconv False 0
# 151 block5c_bn False 0
# 152 block5c_activation False 0
# 153 block5c_se_squeeze False 0
# 154 block5c_se_reshape False 0
# 155 block5c_se_reduce False 0
# 156 block5c_se_expand False 0
# 157 block5c_se_excite False 0
# 158 block5c_project_conv False 0
# 159 block5c_project_bn False 0
# 160 block5c_drop False 0
# 161 block5c_add False 0
# 162 block6a_expand_conv False 0
# 163 block6a_expand_bn False 0
# 164 block6a_expand_activation False 0
# 165 block6a_dwconv_pad False 0
# 166 block6a_dwconv False 0
# 167 block6a_bn False 0
# 168 block6a_activation False 0
# 169 block6a_se_squeeze False 0
# 170 block6a_se_reshape False 0
# 171 block6a_se_reduce False 0
# 172 block6a_se_expand False 0
# 173 block6a_se_excite False 0
# 174 block6a_project_conv False 0
# 175 block6a_project_bn False 0
# 176 block6b_expand_conv False 0
# 177 block6b_expand_bn False 0
# 178 block6b_expand_activation False 0
# 179 block6b_dwconv False 0
# 180 block6b_bn False 0
# 181 block6b_activation False 0
# 182 block6b_se_squeeze False 0
# 183 block6b_se_reshape False 0
# 184 block6b_se_reduce False 0
# 185 block6b_se_expand False 0
# 186 block6b_se_excite False 0
# 187 block6b_project_conv False 0
# 188 block6b_project_bn False 0
# 189 block6b_drop False 0
# 190 block6b_add False 0
# 191 block6c_expand_conv False 0
# 192 block6c_expand_bn False 0
# 193 block6c_expand_activation False 0
# 194 block6c_dwconv False 0
# 195 block6c_bn False 0
# 196 block6c_activation False 0
# 197 block6c_se_squeeze False 0
# 198 block6c_se_reshape False 0
# 199 block6c_se_reduce False 0
# 200 block6c_se_expand False 0
# 201 block6c_se_excite False 0
# 202 block6c_project_conv False 0
# 203 block6c_project_bn False 0
# 204 block6c_drop False 0
# 205 block6c_add False 0
# 206 block6d_expand_conv False 0
# 207 block6d_expand_bn False 0
# 208 block6d_expand_activation False 0
# 209 block6d_dwconv False 0
# 210 block6d_bn False 0
# 211 block6d_activation False 0
# 212 block6d_se_squeeze False 0
# 213 block6d_se_reshape False 0
# 214 block6d_se_reduce False 0
# 215 block6d_se_expand False 0
# 216 block6d_se_excite False 0
# 217 block6d_project_conv False 0
# 218 block6d_project_bn False 0
# 219 block6d_drop False 0
# 220 block6d_add False 0
# 221 block7a_expand_conv False 0
# 222 block7a_expand_bn False 0
# 223 block7a_expand_activation False 0
# 224 block7a_dwconv False 0
# 225 block7a_bn False 0
# 226 block7a_activation False 0
# 227 block7a_se_squeeze False 0
# 228 block7a_se_reshape True 0
# 229 block7a_se_reduce True 2
# 230 block7a_se_expand True 2
# 231 block7a_se_excite True 0
# 232 block7a_project_conv True 1
# 233 block7a_project_bn True 2
# 234 top_conv True 1
# 235 top_bn True 2
# 236 top_activation True 0
# 237 max_pool True 0

# %%
efficientnet_fine_tuning_model = tf.keras.Sequential([
        efficientnet_tune,
        tf.keras.layers.Dense(3, activation='softmax')
    ])

# %%
tf.random.set_seed(seed)

# Compile
efficientnet_fine_tuning_model.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

efficientnet_fine_tuning_model_history = efficientnet_fine_tuning_model.fit(train_data_augmented,
                                  epochs=5,
                                  steps_per_epoch=len(train_data_augmented),
                                  validation_data=test_data,
                                  validation_steps=len(test_data), 
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                   experiment_name="efficientnet_fine_tuning_model")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/efficientnet_fine_tuning_model/20211202-094337
# Epoch 1/5
# 8/8 [==============================] - 44s 4s/step - loss: 6.9004 - accuracy: 0.2978 - val_loss: 3.8079 - val_accuracy: 0.3333
# Epoch 2/5
# 8/8 [==============================] - 21s 3s/step - loss: 5.4235 - accuracy: 0.3200 - val_loss: 2.0281 - val_accuracy: 0.3333
# Epoch 3/5
# 8/8 [==============================] - 28s 4s/step - loss: 2.2421 - accuracy: 0.2933 - val_loss: 3.2520 - val_accuracy: 0.3333
# Epoch 4/5
# 8/8 [==============================] - 24s 3s/step - loss: 2.4930 - accuracy: 0.3600 - val_loss: 1.4549 - val_accuracy: 0.3333
# Epoch 5/5
# 8/8 [==============================] - 22s 3s/step - loss: 2.0201 - accuracy: 0.3378 - val_loss: 1.1665 - val_accuracy: 0.3333

# %% [markdown]
# > ### Conclusion:
# _During this work we chose the '101-food' data according to the student index, visualized it and then prepared for modeling. We've built a few models for categorical image classification and then compared their accuracy:_
# - CNN-model got: 43% accuracy for 10 epochs.
# - Pretrained Resnet model using Adam optimizer got 96% accuracy for 10 epochs.
# - Pretrained EfficientNet model using Adam optimizer got 96% accuracy for 10 epochs.
# - Pretrained Resnet model using SGD optimizer got 98% accuracy for 5 epochs.
# - Pretrained EfficientNet model using SGD optimizer got 97% accuracy for 10 epochs.
# - Pretrained Resnet model with the fine-tuning of the last 10 layers got 70% accuracy for 5 epochs.
# - Pretrained EfficientNet model with the fine-tuning of the last 10 layers got 33% accuracy for 5 epochs.

# %% [markdown]
# #### Lab#5 was made by Ponomarova Darina
